# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
zomato_data = pd.read_csv('zomato.csv', encoding='latin-1')
zomato_data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df = zomato_data.copy()
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# ## The dataset is highly skewed toward the cities included in Delhi-NCR. So, we will summarise all the other cities in Rest of India while those in New Delhi, Ghaziabad, Noida, Gurgaon, Faridabad to Delhi-NCR. Doing this would make our analysis turn toward Delhi-NCR v Rest of India.

# %% [markdown]
# ### Plot the bar graph of number of restaurants present in Delhi NCR vs Rest of India.

# %%
y = [0, 0]
x = ['Delhi NCR', 'Rest of India']
df = df[df['Country Code'] == 1]
city = np.array(df.City)
for i in city:
    if (i == 'New Delhi' or i == 'Ghaziabad' or i == 'Noida' or i == 'Gurgaon' or i == 'Faridabad'):
        y[0] += 1
    else:
        y[1] += 1
plt.bar(x, y)
plt.xlabel('Delhi-NCR vs Rest of India')
plt.ylabel('Number of Restaurants')
plt.show()

# %% [markdown]
# ### Find the cuisines which are not present in restaurant of Delhi NCR but present in rest of India.Check using Zomato API whether this cuisines are actually not served in restaurants of Delhi-NCR or just it due to incomplete dataset.

# %%
df = zomato_data.copy()
df = df[df['Country Code'] == 1]
delhi_ncr = set()
rest_of_india = set()
city = np.array(df.City)
cuisine = np.array(df.Cuisines)
for i in range(0, len(city)):
    j = city[i]
    if (j == 'New Delhi' or j == 'Ghaziabad' or j == 'Noida' or j == 'Gurgaon' or j == 'Faridabad'):
        individual_cuisine = cuisine[i].split(', ')
        for element in individual_cuisine:
            delhi_ncr.add(element)
    else:
        individual_cuisine = cuisine[i].split(', ')
        for element in individual_cuisine:
            rest_of_india.add(element)
answer = rest_of_india - delhi_ncr
for i in answer:
    print(i)
# Out:
# German
# Cajun
# Malwani
# BBQ

# %% [markdown]
# ### Find the top 10 cuisines served by maximum number of restaurants in Delhi NCR and rest of India.

# %%
df = zomato_data.copy()
df = df[df['Country Code'] == 1]
delhi_ncr_dictionary = {}
rest_of_india_dictionary = {}
city = np.array(df.City)
cuisine = np.array(df.Cuisines)
for i in range(0, len(city)):
    j = city[i]
    if (j == 'New Delhi' or j == 'Ghaziabad' or j == 'Noida' or j == 'Gurgaon' or j == 'Faridabad'):
        individual_cuisine = cuisine[i].split(', ')
        for element in individual_cuisine:
            delhi_ncr_dictionary[element] = delhi_ncr_dictionary.get(element, 0) + 1
    else:
        individual_cuisine = cuisine[i].split(', ')
        for element in individual_cuisine:
            rest_of_india_dictionary[element] = rest_of_india_dictionary.get(element, 0) + 1
ncr_cuisine = []
ncr_cuisine_number = []
for i in delhi_ncr_dictionary:
    ncr_cuisine.append(i)
    ncr_cuisine_number.append(delhi_ncr_dictionary[i])
np_ncr_cuisine = np.array(ncr_cuisine)
np_ncr_cuisine_number = np.array(ncr_cuisine_number)
np_ncr_cuisine = np_ncr_cuisine[np.argsort(np_ncr_cuisine_number)]
np_ncr_cuisine_number = np.sort(np_ncr_cuisine_number)
rest_cuisine = []
rest_cuisine_number = []
for i in rest_of_india_dictionary:
    rest_cuisine.append(i)
    rest_cuisine_number.append(rest_of_india_dictionary[i])
np_rest_cuisine = np.array(rest_cuisine)
np_rest_cuisine_number = np.array(rest_cuisine_number)
np_rest_cuisine = np_rest_cuisine[np.argsort(np_rest_cuisine_number)]
np_rest_cuisine_number = np.sort(np_rest_cuisine_number)
print('** Delhi NCR **')
number = []
name = []
for i in range(len(np_ncr_cuisine) - 1, len(np_ncr_cuisine) - 11, -1):
    number.append(np_ncr_cuisine_number[i])
    name.append(np_ncr_cuisine[i])
    print(np_ncr_cuisine[i], np_ncr_cuisine_number[i])
plt.pie(number, labels = name)
plt.show()
print('** Rest Of India **')
number = []
name = []
for i in range(len(np_rest_cuisine) - 1, len(np_rest_cuisine) - 11, -1):
    number.append(np_rest_cuisine_number[i])
    name.append(np_rest_cuisine[i])
    print(np_rest_cuisine[i], np_rest_cuisine_number[i])
plt.pie(number, labels = name)
plt.show()
# Out:
# ** Delhi NCR **
# North Indian 3597
# Chinese 2448
# Fast Food 1866
# Mughlai 933
# Bakery 697
# South Indian 569
# Continental 547
# Desserts 542
# Street Food 538
# Italian 535
# ** Rest Of India **
# North Indian 349
# Chinese 242
# Continental 177
# Italian 147
# Cafe 136
# Fast Food 97
# South Indian 62
# Mughlai 59
# Desserts 55
# Mexican 50

# %% [markdown]
# ## User Rating of a restaurant plays a crucial role in selecting a restaurant or ordering the food from the restaurant.

# %% [markdown]
# ### Write a short detailed analysis of how the rating is affected by the restaurant due following features: Plot a suitable graph to explain your inference.

# %% [markdown]
# #### Number of Votes given Restaurant

# %%
df = zomato_data.copy()
df = df[['Aggregate rating', 'Votes']]
dictionary = {}
ratings = []
votes = []
# for ind in df.index:
#     rating = df['Aggregate rating'][ind]
#     vote = df['Votes'][ind]
#     if rating in dictionary:
#         dictionary[rating] += vote
#     else:
#         dictionary[rating] = vote
# for i in dictionary.keys():
#     ratings.append(i)
#     votes.append(dictionary[i])
for ind in df.index:
    ratings.append(df['Aggregate rating'][ind])
    votes.append(df['Votes'][ind])
np_ratings = np.array(ratings)
np_votes = np.array(votes)
np_votes = np_votes[np.argsort(np_ratings)]
np_ratings = np.sort(np_ratings)
plt.plot(np_ratings, np_votes)
plt.xlabel("Ratings")
plt.ylabel("Number of Votes")
plt.show()

# %% [markdown]
# #### Restaurants serving more number of cuisines.

# %%
df = zomato_data.copy()
df = df[['Cuisines', 'Aggregate rating']]
cuisines = []
ratings = []
df['Cuisines'] = df['Cuisines'].fillna("")
for ind in df.index:
    individual_cuisines = (df['Cuisines'][ind]).split(',')
    number = 0
    for i in individual_cuisines:
        number += 1
    cuisines.append(number)
    ratings.append(df['Aggregate rating'][ind])
np_ratings = np.array(ratings)
np_cuisines = np.array(cuisines)
np_cuisines = np_cuisines[np.argsort(np_ratings)]
np_ratings = np.sort(np_ratings)
plt.plot(np_ratings, np_cuisines)
plt.xlabel("Ratings")
plt.ylabel("Number of Cuisines")
plt.show()

# %% [markdown]
# #### Average Cost of Restaurant

# %%
df = zomato_data.copy()
pd.set_option('display.max_columns', 500)
df = df[['Average Cost for two', 'Aggregate rating']]
costs = []
ratings = []
for ind in df.index:
    costs.append(df['Average Cost for two'][ind])
    ratings.append(df['Aggregate rating'][ind])
np_ratings = np.array(ratings)
np_costs = np.array(costs)
np_ratings = np.sort(np_ratings)
np_costs = np_costs[np.argsort(np_ratings)]
plt.plot(np_ratings, np_costs)
plt.xlabel("Ratings")
plt.ylabel("Costs")
plt.show()

# %% [markdown]
# ### Find the weighted restaurant rating of each locality and find out the top 10 localities with more weighted restaurant rating?

# %% [markdown]
# #### Weighted Restaurant Rating=Σ (number of votes * rating) / Σ (number of votes) .

# %%
df = zomato_data.copy()
df = df[['Locality', 'Aggregate rating', 'Votes']]
weighted_restaurant_rating = []
locality = []
votes = []
ratings = []
for ind in df.index:
    locality.append(df['Locality'][ind])
    ratings.append(df['Aggregate rating'][ind])
    votes.append(df['Votes'][ind])
for i in range(0, len(votes)):
    if (float(votes[i]) == 0):
        weighted_restaurant_rating.append(0)
        continue
    weighted_restaurant_rating.append((float(votes[i]) * float(ratings[i])) / float(votes[i]))
np_locality = np.array(locality)
np_weighted_restaurant_rating = np.array(weighted_restaurant_rating)
np_locality = np_locality[np.argsort(np_weighted_restaurant_rating)]
np_weighted_restaurant_rating = np.sort(np_weighted_restaurant_rating)
for i in range(len(np_locality) - 1, len(np_locality) - 11, -1):
    print(np_locality[i], np_weighted_restaurant_rating[i])
# Out:
# Northern Quarter 4.9
# Venetian Village, Al Maqtaa 4.9
# Old Dutch Hospital, Fort 4.9
# Connaught Place 4.9
# Kenwood 4.9
# New Tampa 4.9
# Fort Street 4.9
# DLF Phase 3 4.9
# Sofitel Philippine Plaza Manila, Pasay City 4.9
# Kapitolyo 4.9

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Plot the bar graph top 15 restaurants have a maximum number of outlets.

# %%
df = zomato_data.copy()
pd.set_option('display.max_columns', 500)
restaurant_name_count = df['Restaurant Name'].value_counts().head(15).to_frame()
restaurant_names = df['Restaurant Name'].value_counts().head(15).index.tolist()
restaurant_counts = df['Restaurant Name'].value_counts().head(15).values.tolist()
plt.bar(restaurant_names, restaurant_counts)
plt.xticks(rotation=75)
plt.xlabel("Name of Restaurants")
plt.ylabel("Number of Outlets")
plt.show()

# %% [markdown]
# ### Plot the histogram of aggregate rating of restaurant( drop the unrated restaurant).

# %%
df = zomato_data.copy()
df = df[['Aggregate rating']]
ratings = []
for ind in df.index:
    ratings.append(df['Aggregate rating'][ind])
result = []
for i in ratings:
    if (i != 0.0):
        result.append(i)
plt.hist(result)
plt.xlabel("Rating of restaurants")
plt.show()

# %% [markdown]
# ### Plot the bar graph top 10 restaurants in the data with the highest number of votes.

# %%
df = zomato_data.copy()
pd.set_option('display.max_columns', 500)
df = df[['Restaurant Name', 'Votes']]
votes = []
names = []
for ind in df.index:
    votes.append(df['Votes'][ind])
    names.append(df['Restaurant Name'][ind])
np_names = np.array(names)
np_votes = np.array(votes)
np_votes = np.sort(np_votes)
np_names = np_names[np.argsort(np_votes)]
x = []
y = []
for i in range(len(np_names) - 1, len(np_names) - 11, -1):
    x.append(np_names[i])
    y.append(np_votes[i])
plt.bar(x, y)
plt.xticks(rotation=75)
plt.xlabel("Name of Restaurants")
plt.ylabel("Number of Votes")
plt.show()

# %% [markdown]
# ### Plot the pie graph of top 10 cuisines present in restaurants in the USA.

# %%
df = zomato_data.copy()
df = df[df['Country Code'] == 216]
df = df[['Cuisines', 'Aggregate rating']]
df
ratings = []
cuisines = []
for ind in df.index:
    ratings.append(df['Aggregate rating'][ind])
    cuisines.append(df['Cuisines'][ind])
np_cuisines = np.array(cuisines)
np_ratings = np.array(ratings)
np_ratings = np.sort(np_ratings)
np_cuisines = np_cuisines[np.argsort(np_ratings)]
x = []
y = []
for i in range(len(np_cuisines) - 1, len(np_cuisines) - 11, -1):
    x.append(np_cuisines[i])
    y.append(np_ratings[i])
plt.pie(y, labels = x)
plt.title("Top 10 Cuisines")
plt.show()

# %% [markdown]
# ### Plot the bubble graph of a number of Restaurants present in the city of India and keeping the weighted restaurant rating of the city in a bubble.

# %%
df = zomato_data.copy()
df = df[df['Country Code'] == 1]
df = df[['City', 'Aggregate rating', 'Votes']]
city_names = df['City'].value_counts().index.tolist()
restaurant_counts = df['City'].value_counts().values.tolist()
weighted_restaurant_rating = []
city = []
votes = []
ratings = []
for ind in df.index:
    city.append(df['City'][ind])
    ratings.append(df['Aggregate rating'][ind])
    votes.append(df['Votes'][ind])
for i in range(0, len(votes)):
    if (float(votes[i]) == 0):
        weighted_restaurant_rating.append(0)
        continue
    weighted_restaurant_rating.append((float(votes[i]) * float(ratings[i])) / float(votes[i]))
dictionary = {}
for i in range(0, len(city)):
    if city[i] in dictionary.keys():
        dictionary[city[i]] += weighted_restaurant_rating[i]
    else:
        dictionary[city[i]] = weighted_restaurant_rating[i]
for i in range(0, len(restaurant_counts)):
    dictionary[city_names[i]] = dictionary[city_names[i]] / restaurant_counts[i]
weighted = []
for i in dictionary.keys():
    weighted.append(dictionary[i])
plt.scatter(city_names, restaurant_counts, s = weighted)
plt.xticks(rotation=90)
plt.show()
