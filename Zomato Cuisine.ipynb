# %% [markdown]
# ### Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API.
# ### Print the cuisine_id.

# %%
import requests
header = {'user-key': '61b413ded5143f11855a455e7cf44568'}
response = requests.get('https://developers.zomato.com/api/v2.1/cuisines', headers = header, params = {'city_id': 280})
data = response.json()
data
# Out:
# {'cuisines': [{'cuisine': {'cuisine_id': 1035, 'cuisine_name': 'Afghan'}},
#   {'cuisine': {'cuisine_id': 6, 'cuisine_name': 'Afghani'}},
#   {'cuisine': {'cuisine_id': 152, 'cuisine_name': 'African'}},
#   {'cuisine': {'cuisine_id': 1, 'cuisine_name': 'American'}},
#   {'cuisine': {'cuisine_id': 954, 'cuisine_name': 'Amish'}},
#   {'cuisine': {'cuisine_id': 151, 'cuisine_name': 'Argentine'}},
#   {'cuisine': {'cuisine_id': 175, 'cuisine_name': 'Armenian'}},
#   {'cuisine': {'cuisine_id': 3, 'cuisine_name': 'Asian'}},
#   {'cuisine': {'cuisine_id': 131, 'cuisine_name': 'Australian'}},
#   {'cuisine': {'cuisine_id': 201, 'cuisine_name': 'Austrian'}},
#   {'cuisine': {'cuisine_id': 193, 'cuisine_name': 'BBQ'}},
#   {'cuisine': {'cuisine_id': 955, 'cuisine_name': 'Bagels'}},
#   {'cuisine': {'cuisine_id': 5, 'cuisine_name': 'Bakery'}},
#   {'cuisine': {'cuisine_id': 227, 'cuisine_name': 'Bar Food'}},
#   {'cuisine': {'cuisine_id': 132, 'cuisine_name': 'Belgian'}},
# ...

# %%
cuisines = data['cuisines']
cuisines
# Out:
# [{'cuisine': {'cuisine_id': 1035, 'cuisine_name': 'Afghan'}},
#  {'cuisine': {'cuisine_id': 6, 'cuisine_name': 'Afghani'}},
#  {'cuisine': {'cuisine_id': 152, 'cuisine_name': 'African'}},
#  {'cuisine': {'cuisine_id': 1, 'cuisine_name': 'American'}},
#  {'cuisine': {'cuisine_id': 954, 'cuisine_name': 'Amish'}},
#  {'cuisine': {'cuisine_id': 151, 'cuisine_name': 'Argentine'}},
#  {'cuisine': {'cuisine_id': 175, 'cuisine_name': 'Armenian'}},
#  {'cuisine': {'cuisine_id': 3, 'cuisine_name': 'Asian'}},
#  {'cuisine': {'cuisine_id': 131, 'cuisine_name': 'Australian'}},
#  {'cuisine': {'cuisine_id': 201, 'cuisine_name': 'Austrian'}},
#  {'cuisine': {'cuisine_id': 193, 'cuisine_name': 'BBQ'}},
#  {'cuisine': {'cuisine_id': 955, 'cuisine_name': 'Bagels'}},
#  {'cuisine': {'cuisine_id': 5, 'cuisine_name': 'Bakery'}},
#  {'cuisine': {'cuisine_id': 227, 'cuisine_name': 'Bar Food'}},
#  {'cuisine': {'cuisine_id': 132, 'cuisine_name': 'Belgian'}},
# ...

# %%
for i in range(0, len(cuisines)):
    if (cuisines[i]['cuisine']['cuisine_name'] == 'Mexican'):
        print(cuisines[i]['cuisine']['cuisine_id'])
        break
# Out:
# 73

# %% [markdown]
# ### Fetch the entityid and entitytype of place Connaught Place.
# ### Print the entityid and entitytype,

# %%
import requests
header = {'user-key': '61b413ded5143f11855a455e7cf44568'}
response = requests.get('https://developers.zomato.com/api/v2.1/locations', headers = header, params = {'query': 'Connaught'})
data = response.json()
data
# Out:
# {'location_suggestions': [{'entity_type': 'subzone',
#    'entity_id': 104,
#    'title': 'Connaught Place, New Delhi',
#    'latitude': 28.632832,
#    'longitude': 77.219688,
#    'city_id': 1,
#    'city_name': 'Delhi NCR',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
location_suggestions = data['location_suggestions']
location_suggestions
# Out:
# [{'entity_type': 'subzone',
#   'entity_id': 104,
#   'title': 'Connaught Place, New Delhi',
#   'latitude': 28.632832,
#   'longitude': 77.219688,
#   'city_id': 1,
#   'city_name': 'Delhi NCR',
#   'country_id': 1,
#   'country_name': 'India'}]

# %%
print(location_suggestions[0]['entity_type'], location_suggestions[0]['entity_id'])
# Out:
# subzone 104

# %% [markdown]
# ### Fetch the top 10 best-rated restaurant serving ‘Mexican’ cuisine present in Connaught Place.
# ### Print the restaurant name, user rating and restaurant id.

# %%
import requests
header = {'user-key': '61b413ded5143f11855a455e7cf44568'}
response = requests.get('https://developers.zomato.com/api/v2.1/search', headers = header, params = {'entity_id': 104, 'entity_type': 'subzone', 'q': 'Connaught Place', 'count': 10, 'sort': 'rating', 'cuisines': [73]})
data = response.json()
data
# Out:
# {'results_found': 46,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'res_id': 18851371,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '61b413ded5143f11855a455e7cf44568',
#     'id': '18851371',
#     'name': 'Station Bar',
#     'url': 'https://www.zomato.com/ncr/station-bar-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'F-60, 2nd Floor, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6310020285',
#      'longitude': '77.2196914628',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Asian, Continental, North Indian, Mughlai, Fast Food, Beverages',
#     'timings': 'Mon-Sun (12 Noon to 1 AM)',
# ...

# %%
restaurants = data['restaurants']
restaurants
# Out:
# [{'restaurant': {'R': {'res_id': 18851371,
#     'is_grocery_store': False,
#     'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#    'apikey': '61b413ded5143f11855a455e7cf44568',
#    'id': '18851371',
#    'name': 'Station Bar',
#    'url': 'https://www.zomato.com/ncr/station-bar-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': 'F-60, 2nd Floor, Connaught Place, New Delhi',
#     'locality': 'Connaught Place',
#     'city': 'New Delhi',
#     'city_id': 1,
#     'latitude': '28.6310020285',
#     'longitude': '77.2196914628',
#     'zipcode': '',
#     'country_id': 1,
#     'locality_verbose': 'Connaught Place, New Delhi'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Continental, North Indian, Mughlai, Fast Food, Beverages',
#    'timings': 'Mon-Sun (12 Noon to 1 AM)',
#    'average_cost_for_two': 1700,
#    'price_range': 3,
#    'currency': 'Rs.',
#    'highlights': ['Lunch',
#     'Cash',
# ...

# %%
for i in range(0, len(restaurants)):
    print(restaurants[i]['restaurant']['name'], restaurants[i]['restaurant']['user_rating']['aggregate_rating'], restaurants[i]['restaurant']['R']['res_id'])
# Out:
# Station Bar 4.5 18851371
# Tamasha 4.4 18238278
# Xero Degrees 4.4 18729557
# Master Of Malts 4.4 18391149
# Chili's Grill & Bar 4.4 18537536
# Local 4.3 18382360
# The Junkyard Cafe 4.3 313256
# Ministry Of Beer 4.3 18418277
# Teddy Boy 4.3 18281985
# Openhouse Cafe 4.3 312601

# %% [markdown]
# ### Fetch the category id of category type ‘Cafes’ using Zomato API.
# ### Print the category_id.

# %%
import requests
header = {'user-key': '61b413ded5143f11855a455e7cf44568'}
response = requests.get('https://developers.zomato.com/api/v2.1/categories', headers = header)
data = response.json()
data
# Out:
# {'categories': [{'categories': {'id': 1, 'name': 'Delivery'}},
#   {'categories': {'id': 2, 'name': 'Dine-out'}},
#   {'categories': {'id': 3, 'name': 'Nightlife'}},
#   {'categories': {'id': 4, 'name': 'Catching-up'}},
#   {'categories': {'id': 5, 'name': 'Takeaway'}},
#   {'categories': {'id': 6, 'name': 'Cafes'}},
#   {'categories': {'id': 7, 'name': 'Daily Menus'}},
#   {'categories': {'id': 8, 'name': 'Breakfast'}},
#   {'categories': {'id': 9, 'name': 'Lunch'}},
#   {'categories': {'id': 10, 'name': 'Dinner'}},
#   {'categories': {'id': 11, 'name': 'Pubs & Bars'}},
#   {'categories': {'id': 13, 'name': 'Pocket Friendly Delivery'}},
#   {'categories': {'id': 14, 'name': 'Clubs & Lounges'}}]}

# %%
categories = data['categories']
categories
# Out:
# [{'categories': {'id': 1, 'name': 'Delivery'}},
#  {'categories': {'id': 2, 'name': 'Dine-out'}},
#  {'categories': {'id': 3, 'name': 'Nightlife'}},
#  {'categories': {'id': 4, 'name': 'Catching-up'}},
#  {'categories': {'id': 5, 'name': 'Takeaway'}},
#  {'categories': {'id': 6, 'name': 'Cafes'}},
#  {'categories': {'id': 7, 'name': 'Daily Menus'}},
#  {'categories': {'id': 8, 'name': 'Breakfast'}},
#  {'categories': {'id': 9, 'name': 'Lunch'}},
#  {'categories': {'id': 10, 'name': 'Dinner'}},
#  {'categories': {'id': 11, 'name': 'Pubs & Bars'}},
#  {'categories': {'id': 13, 'name': 'Pocket Friendly Delivery'}},
#  {'categories': {'id': 14, 'name': 'Clubs & Lounges'}}]

# %%
for i in range(0, len(categories)):
    if (categories[i]['categories']['name'] == 'Cafes'):
        print(categories[i]['categories']['id'])
        break
# Out:
# 6

# %% [markdown]
# ### Fetch the best-rated restaurant for ‘Mexican’ cuisine with category type ‘ Cafes’ present in Connaught Place using Zomato API.
# ### Print the restaurant name, user rating and restaurant id.

# %%
import requests
header = {'user-key': '61b413ded5143f11855a455e7cf44568'}
response = requests.get('https://developers.zomato.com/api/v2.1/search', headers = header, params = {'entity_id': 104, 'entity_type': 'subzone', 'cuisines': [73], 'category': 6, 'sort': 'rating'})
data = response.json()
data
# Out:
# {'results_found': 4,
#  'results_start': 0,
#  'results_shown': 4,
#  'restaurants': [{'restaurant': {'R': {'res_id': 18729557,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '61b413ded5143f11855a455e7cf44568',
#     'id': '18729557',
#     'name': 'Xero Degrees',
#     'url': 'https://www.zomato.com/ncr/xero-degrees-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'L-23/9, Middle Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6343423459',
#      'longitude': '77.2213641554',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Cafe, Fast Food, Beverages',
#     'timings': '12:30PM to 11PM (Mon-Sun)',
#     'average_cost_for_two': 750,
# ...

# %%
restaurants = data['restaurants']
restaurants
# Out:
# [{'restaurant': {'R': {'res_id': 18729557,
#     'is_grocery_store': False,
#     'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#    'apikey': '61b413ded5143f11855a455e7cf44568',
#    'id': '18729557',
#    'name': 'Xero Degrees',
#    'url': 'https://www.zomato.com/ncr/xero-degrees-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': 'L-23/9, Middle Circle, Connaught Place, New Delhi',
#     'locality': 'Connaught Place',
#     'city': 'New Delhi',
#     'city_id': 1,
#     'latitude': '28.6343423459',
#     'longitude': '77.2213641554',
#     'zipcode': '',
#     'country_id': 1,
#     'locality_verbose': 'Connaught Place, New Delhi'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Cafe, Fast Food, Beverages',
#    'timings': '12:30PM to 11PM (Mon-Sun)',
#    'average_cost_for_two': 750,
#    'price_range': 2,
#    'currency': 'Rs.',
#    'highlights': ['Dinner',
#     'Cash',
#     'Takeaway Available',
# ...

# %%
for i in range(0, len(restaurants)):
    print(restaurants[i]['restaurant']['name'], restaurants[i]['restaurant']['user_rating']['aggregate_rating'], restaurants[i]['restaurant']['R']['res_id'])
# Out:
# Xero Degrees 4.4 18729557
# Chaayos - Meri Wali Chai 4.2 18237315
# The Art House Bar n Cafe 4.0 18863766
# Cafe Coffee Day - The Square 3.5 303034

# %% [markdown]
# ### Fetch the latest review of the best-rated restaurant for ‘Mexican’ cuisine with Category type ‘Cafes’ present in Connaught Place using Zomato API.
# ### Print the name of user ,user rating and review text.

# %%
import requests
header = {'user-key': '61b413ded5143f11855a455e7cf44568'}
response = requests.get('https://developers.zomato.com/api/v2.1/reviews', headers = header, params = {'res_id': 18729557})
data = response.json()
data
# Out:
# {'reviews_count': 1399,
#  'reviews_start': 0,
#  'reviews_shown': 5,
#  'user_reviews': [{'review': {'rating': 3,
#     'review_text': "the only thing which bothered me was the glass box broke on my hand & ended up cuts and bleeding while opening the packaging. It'd be better if they use a container that's safer than this",
#     'id': 52426301,
#     'rating_color': 'CDD614',
#     'review_time_friendly': 'yesterday',
#     'rating_text': 'Average',
#     'timestamp': 1611418072,
#     'likes': 0,
#     'user': {'name': 'Ashima Bhasin',
#      'zomato_handle': '',
#      'foodie_color': 'ffd35d',
#      'profile_url': 'https://www.zomato.com/users/ashima-bhasin-68068774?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8a0/29d8448a64cd5b89b51485372d3b28a0.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/68068774'},
#     'comments_count': 0}},
# ...

# %%
user_reviews = data['user_reviews']
user_reviews
# Out:
# [{'review': {'rating': 3,
#    'review_text': "the only thing which bothered me was the glass box broke on my hand & ended up cuts and bleeding while opening the packaging. It'd be better if they use a container that's safer than this",
#    'id': 52426301,
#    'rating_color': 'CDD614',
#    'review_time_friendly': 'yesterday',
#    'rating_text': 'Average',
#    'timestamp': 1611418072,
#    'likes': 0,
#    'user': {'name': 'Ashima Bhasin',
#     'zomato_handle': '',
#     'foodie_color': 'ffd35d',
#     'profile_url': 'https://www.zomato.com/users/ashima-bhasin-68068774?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8a0/29d8448a64cd5b89b51485372d3b28a0.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#     'profile_deeplink': 'zomato://u/68068774'},
#    'comments_count': 0}},
#  {'review': {'rating': 5,
# ...

# %%
for i in range(0, len(user_reviews)):
    print(user_reviews[i]['review']['user']['name'], user_reviews[i]['review']['rating'], user_reviews[i]['review']['review_text'])
# Out:
# Ashima Bhasin 3 the only thing which bothered me was the glass box broke on my hand & ended up cuts and bleeding while opening the packaging. It'd be better if they use a container that's safer than this
# Tanya Khanna 5 Located in the middle circle of the heart of Delhi (CP), this is the best place where you can munch their delicious food. The place has a lot to offer from veg/non - veg fries to cool drinks and waffles.  So, I have been here for quiet a few times now and I felt that it’s time to write something about this amazing place.  I have ordered ordered peri peri fries that were just mouth watering and Ama-h-zing and one of the best in town.  Then on being asked bout the best pizzas, the service man suggested to try out their crispy peppy paneer pizza with cheese burst which turned out to be sooo good.  Just a small setting in CP outlet is a slight drawback otherwise this place is lit ! Have tried both Vijay nagar and CP outlet and both are really great!!
# Siddharth Verma 5
# ...
